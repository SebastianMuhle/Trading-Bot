# %% [markdown]
# # Trading Bot
#
# Welcome to our trading bot for Dow Jones stocks. This bot helps you to earn a lot of money.
# Just follow the instructions.

# %% [markdown]
# ### Before we can start, we first have to import a few libraries

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from own_jupyter_controls import dropdown_widget, generate_file_path_for_stock_data, network_architecture_widget
from stock_pred import train_bot
from trading import trading
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Selecting stock
# Please select the ticker symbol of the Dow Jones stock your interested in.
# First run the cell. Then select the ticker symbol from the dropdown-menu, then run the next Cell.

# %%
widget = dropdown_widget()
display(widget)
# Out:
# interactive(children=(Dropdown(description='Symbol', options=('MMM', 'AXP', 'AAPL', 'BA', 'CAT', 'CVX', 'CSCO'…

# %%
file_path = generate_file_path_for_stock_data(widget.kwargs['x'])
# Uncomment the following line if the widget does not work and add your own ticker symbol 'data/daily_[TickerSymbol].csv'
# file_path = 'data/daily_MSFT.csv'
print("The file path to your data is '" + file_path + "'")
# Out:
# The file path to your data is 'data/daily_CAT.csv'

# %% [markdown]
# ## Predicting stock
# Next we train a neural network to learn to predict the course development of our selected stock.
# <br>
# <br>
# But first we have to select the hyperparameters of our network!

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = False
ema12 = False 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 5s - loss: 0.0077 - val_loss: 5.5836e-04
# Epoch 2/50
#  - 4s - loss: 0.0010 - val_loss: 0.0010
# Epoch 3/50
#  - 4s - loss: 7.6129e-04 - val_loss: 3.5784e-04
# Epoch 4/50
#  - 4s - loss: 5.9182e-04 - val_loss: 9.3309e-04
# Epoch 5/50
#  - 5s - loss: 5.4261e-04 - val_loss: 2.7405e-04
# Epoch 6/50
#  - 4s - loss: 4.7592e-04 - val_loss: 9.4505e-04
# Epoch 7/50
#  - 4s - loss: 4.2383e-04 - val_loss: 2.6569e-04
# Epoch 8/50
#  - 4s - loss: 3.7805e-04 - val_loss: 4.3713e-04
# Epoch 9/50
#  - 4s - loss: 3.8377e-04 - val_loss: 1.9888e-04
# Epoch 10/50
#  - 4s - loss: 3.3337e-04 - val_loss: 1.4805e-04
# Epoch 11/50
#  - 4s - loss: 3.1308e-04 - val_loss: 2.4762e-04
# Epoch 12/50
#  - 4s - loss: 2.9886e-04 - val_loss: 1.6783e-04
# Epoch 13/50
#  - 4s - loss: 3.0204e-04 - val_loss: 1.2042e-04
# Epoch 14/50
#  - 4s - loss: 3.1137e-04 - val_loss: 1.2011e-04
# Epoch 15/50
#  - 4s - loss: 3.0817e-04 - val_loss: 1.2851e-04
# Epoch 16/50
#  - 3s - loss: 2.8355e-04 - val_loss: 1.2930e-04
# Epoch 17/50
#  - 4s - loss: 2.6357e-04 - val_loss: 6.9752e-04
# Epoch 18/50
#  - 4s - loss: 2.7687e-04 - val_loss: 1.1653e-04
# Epoch 19/50
#  - 3s - loss: 2.7714e-04 - val_loss: 3.5584e-04
# Epoch 20/50
#  - 3s - loss: 2.7268e-04 - val_loss: 1.4827e-04
# Epoch 21/50
#  - 3s - loss: 2.5796e-04 - val_loss: 1.1337e-04
# Epoch 22/50
#  - 4s - loss: 2.5304e-04 - val_loss: 1.1211e-04
# Epoch 23/50
#  - 3s - loss: 2.6974e-04 - val_loss: 9.9956e-05
# Epoch 24/50
#  - 3s - loss: 2.6569e-04 - val_loss: 1.0138e-04
# Epoch 25/50
#  - 4s - loss: 2.7525e-04 - val_loss: 1.6624e-04
# Epoch 26/50
#  - 4s - loss: 2.6772e-04 - val_loss: 1.3463e-04
# Epoch 27/50
#  - 3s - loss: 2.4296e-04 - val_loss: 1.0648e-04
# Epoch 28/50
#  - 3s - loss: 2.4486e-04 - val_loss: 1.0042e-04
# Epoch 29/50
#  - 3s - loss: 2.4320e-04 - val_loss: 1.0099e-04
# Epoch 30/50
#  - 4s - loss: 2.3665e-04 - val_loss: 1.1313e-04
# Epoch 31/50
#  - 4s - loss: 2.3875e-04 - val_loss: 1.2459e-04
# Epoch 32/50
#  - 4s - loss: 2.3382e-04 - val_loss: 9.0866e-05
# Epoch 33/50
#  - 4s - loss: 2.3480e-04 - val_loss: 1.6545e-04
# Epoch 34/50
#  - 3s - loss: 2.3916e-04 - val_loss: 1.0585e-04
# Epoch 35/50
#  - 4s - loss: 2.2965e-04 - val_loss: 3.0701e-04
# Epoch 36/50
#  - 5s - loss: 2.7296e-04 - val_loss: 1.7071e-04
# Epoch 37/50
#  - 3s - loss: 2.3479e-04 - val_loss: 2.7495e-04
# Epoch 38/50
#  - 4s - loss: 2.4159e-04 - val_loss: 1.5066e-04
# Epoch 39/50
#  - 4s - loss: 2.3699e-04 - val_loss: 2.2863e-04
# Epoch 40/50
#  - 4s - loss: 2.4225e-04 - val_loss: 2.3921e-04
# Epoch 41/50
#  - 6s - loss: 2.2846e-04 - val_loss: 3.2509e-04
# Epoch 42/50
#  - 4s - loss: 2.3112e-04 - val_loss: 2.0928e-04
# Epoch 43/50
#  - 4s - loss: 2.3831e-04 - val_loss: 1.1778e-04
# Epoch 44/50
#  - 4s - loss: 2.4007e-04 - val_loss: 1.8557e-04
# Epoch 45/50
#  - 4s - loss: 2.3644e-04 - val_loss: 5.0379e-04
# Epoch 46/50
#  - 3s - loss: 2.4485e-04 - val_loss: 1.1440e-04
# Epoch 47/50
#  - 3s - loss: 2.2453e-04 - val_loss: 1.0985e-04
# Epoch 48/50
#  - 3s - loss: 2.2396e-04 - val_loss: 9.5288e-05
# Epoch 49/50
#  - 4s - loss: 2.1991e-04 - val_loss: 1.0262e-04
# Epoch 50/50
#  - 4s - loss: 2.1364e-04 - val_loss: 1.0625e-04
# 21.91196908708521
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 39
# sells: 32
# The money our bot would have earned
# earnings: $85.01032539440678

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = True 
ma7 = False
ma21 = False 
ma_his_window = False
ema12 = False 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4032 samples, validate on 448 samples
# Epoch 1/50
#  - 5s - loss: 0.0609 - val_loss: 0.0016
# Epoch 2/50
#  - 4s - loss: 0.0021 - val_loss: 9.2552e-04
# Epoch 3/50
#  - 4s - loss: 0.0017 - val_loss: 4.2945e-04
# Epoch 4/50
#  - 3s - loss: 0.0015 - val_loss: 2.4265e-04
# Epoch 5/50
#  - 4s - loss: 0.0012 - val_loss: 2.1944e-04
# Epoch 6/50
#  - 3s - loss: 9.4927e-04 - val_loss: 3.8676e-04
# Epoch 7/50
#  - 3s - loss: 8.7839e-04 - val_loss: 5.2570e-04
# Epoch 8/50
#  - 4s - loss: 8.1362e-04 - val_loss: 1.5431e-04
# Epoch 9/50
#  - 4s - loss: 7.2694e-04 - val_loss: 2.7674e-04
# Epoch 10/50
#  - 4s - loss: 6.0592e-04 - val_loss: 4.0175e-04
# Epoch 11/50
#  - 3s - loss: 5.6348e-04 - val_loss: 1.5754e-04
# Epoch 12/50
#  - 3s - loss: 5.5336e-04 - val_loss: 1.8312e-04
# Epoch 13/50
#  - 3s - loss: 5.1215e-04 - val_loss: 1.9189e-04
# Epoch 14/50
#  - 3s - loss: 4.9108e-04 - val_loss: 2.6266e-04
# Epoch 15/50
#  - 3s - loss: 4.6074e-04 - val_loss: 2.2034e-04
# Epoch 16/50
#  - 4s - loss: 4.5872e-04 - val_loss: 2.4114e-04
# Epoch 17/50
#  - 4s - loss: 4.2565e-04 - val_loss: 3.3593e-04
# Epoch 18/50
#  - 4s - loss: 4.0196e-04 - val_loss: 1.6753e-04
# Epoch 19/50
#  - 3s - loss: 4.0829e-04 - val_loss: 1.9445e-04
# Epoch 20/50
#  - 4s - loss: 3.6619e-04 - val_loss: 2.0008e-04
# Epoch 21/50
#  - 4s - loss: 3.5387e-04 - val_loss: 1.6004e-04
# Epoch 22/50
#  - 4s - loss: 3.5989e-04 - val_loss: 2.1677e-04
# Epoch 23/50
#  - 4s - loss: 3.4657e-04 - val_loss: 6.1994e-04
# Epoch 24/50
#  - 4s - loss: 3.4802e-04 - val_loss: 2.2578e-04
# Epoch 25/50
#  - 4s - loss: 3.3558e-04 - val_loss: 1.7152e-04
# Epoch 26/50
#  - 4s - loss: 3.1734e-04 - val_loss: 1.4628e-04
# Epoch 27/50
#  - 4s - loss: 3.0584e-04 - val_loss: 2.8483e-04
# Epoch 28/50
#  - 5s - loss: 3.1727e-04 - val_loss: 1.4768e-04
# Epoch 29/50
#  - 5s - loss: 3.0214e-04 - val_loss: 3.6141e-04
# Epoch 30/50
#  - 4s - loss: 3.0237e-04 - val_loss: 1.5793e-04
# Epoch 31/50
#  - 5s - loss: 3.1336e-04 - val_loss: 6.3634e-04
# Epoch 32/50
#  - 4s - loss: 2.8615e-04 - val_loss: 1.4834e-04
# Epoch 33/50
#  - 4s - loss: 3.0230e-04 - val_loss: 3.9648e-04
# Epoch 34/50
#  - 4s - loss: 2.8012e-04 - val_loss: 1.1678e-04
# Epoch 35/50
#  - 4s - loss: 3.0020e-04 - val_loss: 2.4535e-04
# Epoch 36/50
#  - 3s - loss: 2.6221e-04 - val_loss: 1.8485e-04
# Epoch 37/50
#  - 4s - loss: 2.8860e-04 - val_loss: 1.1325e-04
# Epoch 38/50
#  - 4s - loss: 2.7762e-04 - val_loss: 2.0359e-04
# Epoch 39/50
#  - 5s - loss: 2.7659e-04 - val_loss: 1.1342e-04
# Epoch 40/50
#  - 4s - loss: 2.6468e-04 - val_loss: 1.5906e-04
# Epoch 41/50
#  - 6s - loss: 2.5571e-04 - val_loss: 1.4194e-04
# Epoch 42/50
#  - 5s - loss: 2.5363e-04 - val_loss: 1.5877e-04
# Epoch 43/50
#  - 5s - loss: 2.5194e-04 - val_loss: 2.1276e-04
# Epoch 44/50
#  - 4s - loss: 2.6886e-04 - val_loss: 1.2030e-04
# Epoch 45/50
#  - 4s - loss: 2.6129e-04 - val_loss: 1.4087e-04
# Epoch 46/50
#  - 4s - loss: 2.4819e-04 - val_loss: 1.0115e-04
# Epoch 47/50
#  - 4s - loss: 2.4631e-04 - val_loss: 1.0522e-04
# Epoch 48/50
#  - 4s - loss: 2.5101e-04 - val_loss: 1.5148e-04
# Epoch 49/50
#  - 4s - loss: 2.5569e-04 - val_loss: 1.0982e-04
# Epoch 50/50
#  - 4s - loss: 2.4448e-04 - val_loss: 1.8569e-04
# 22.424945719405557
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 57
# sells: 36
# The money our bot would have earned
# earnings: $126.21792025916073

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = True
ma21 = False 
ma_his_window = False
ema12 = False 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 5s - loss: 0.0177 - val_loss: 1.5753e-04
# Epoch 2/50
#  - 4s - loss: 6.9714e-04 - val_loss: 1.2238e-04
# Epoch 3/50
#  - 4s - loss: 5.4474e-04 - val_loss: 1.1853e-04
# Epoch 4/50
#  - 4s - loss: 4.9499e-04 - val_loss: 7.2503e-05
# Epoch 5/50
#  - 4s - loss: 4.1836e-04 - val_loss: 1.2504e-04
# Epoch 6/50
#  - 4s - loss: 3.5487e-04 - val_loss: 6.2328e-05
# Epoch 7/50
#  - 4s - loss: 3.4677e-04 - val_loss: 1.3482e-04
# Epoch 8/50
#  - 3s - loss: 3.1673e-04 - val_loss: 1.0151e-04
# Epoch 9/50
#  - 3s - loss: 3.0040e-04 - val_loss: 8.0194e-05
# Epoch 10/50
#  - 3s - loss: 2.8866e-04 - val_loss: 7.2982e-05
# Epoch 11/50
#  - 3s - loss: 2.5316e-04 - val_loss: 5.8013e-05
# Epoch 12/50
#  - 3s - loss: 2.3409e-04 - val_loss: 8.5003e-05
# Epoch 13/50
#  - 3s - loss: 2.3443e-04 - val_loss: 2.6735e-04
# Epoch 14/50
#  - 3s - loss: 2.2121e-04 - val_loss: 1.0103e-04
# Epoch 15/50
#  - 4s - loss: 2.2989e-04 - val_loss: 5.3165e-05
# Epoch 16/50
#  - 4s - loss: 2.1248e-04 - val_loss: 2.6538e-04
# Epoch 17/50
#  - 3s - loss: 2.4334e-04 - val_loss: 4.9240e-05
# Epoch 18/50
#  - 3s - loss: 2.0286e-04 - val_loss: 1.5026e-04
# Epoch 19/50
#  - 4s - loss: 2.1700e-04 - val_loss: 2.0857e-04
# Epoch 20/50
#  - 3s - loss: 1.9362e-04 - val_loss: 1.2394e-04
# Epoch 21/50
#  - 3s - loss: 1.9437e-04 - val_loss: 1.9094e-04
# Epoch 22/50
#  - 4s - loss: 2.1107e-04 - val_loss: 7.9701e-05
# Epoch 23/50
#  - 4s - loss: 1.9174e-04 - val_loss: 5.4544e-05
# Epoch 24/50
#  - 4s - loss: 1.8265e-04 - val_loss: 5.5262e-05
# Epoch 25/50
#  - 4s - loss: 1.6848e-04 - val_loss: 1.0354e-04
# Epoch 26/50
#  - 3s - loss: 1.9099e-04 - val_loss: 4.5183e-05
# Epoch 27/50
#  - 3s - loss: 1.8945e-04 - val_loss: 5.1021e-05
# Epoch 28/50
#  - 3s - loss: 1.7301e-04 - val_loss: 7.0082e-05
# Epoch 29/50
#  - 4s - loss: 1.6043e-04 - val_loss: 5.9222e-05
# Epoch 30/50
#  - 4s - loss: 1.6728e-04 - val_loss: 4.0966e-05
# Epoch 31/50
#  - 4s - loss: 1.6667e-04 - val_loss: 1.3199e-04
# Epoch 32/50
#  - 4s - loss: 1.6396e-04 - val_loss: 1.2968e-04
# Epoch 33/50
#  - 3s - loss: 1.7109e-04 - val_loss: 6.7299e-05
# Epoch 34/50
#  - 3s - loss: 1.5986e-04 - val_loss: 6.3083e-05
# Epoch 35/50
#  - 3s - loss: 1.5916e-04 - val_loss: 4.4664e-05
# Epoch 36/50
#  - 3s - loss: 1.6599e-04 - val_loss: 3.6192e-05
# Epoch 37/50
#  - 3s - loss: 1.6259e-04 - val_loss: 4.6510e-05
# Epoch 38/50
#  - 3s - loss: 1.6045e-04 - val_loss: 4.2696e-05
# Epoch 39/50
#  - 3s - loss: 1.6667e-04 - val_loss: 1.1914e-04
# Epoch 40/50
#  - 3s - loss: 1.5745e-04 - val_loss: 1.0890e-04
# Epoch 41/50
#  - 3s - loss: 1.4453e-04 - val_loss: 4.9317e-05
# Epoch 42/50
#  - 4s - loss: 1.6475e-04 - val_loss: 7.0210e-05
# Epoch 43/50
#  - 3s - loss: 1.6041e-04 - val_loss: 3.7589e-05
# Epoch 44/50
#  - 3s - loss: 1.4804e-04 - val_loss: 3.7028e-05
# Epoch 45/50
#  - 3s - loss: 1.4368e-04 - val_loss: 1.9235e-04
# Epoch 46/50
#  - 3s - loss: 1.4693e-04 - val_loss: 3.2638e-05
# Epoch 47/50
#  - 3s - loss: 1.4822e-04 - val_loss: 7.6840e-04
# Epoch 48/50
#  - 4s - loss: 2.4767e-04 - val_loss: 3.1193e-05
# Epoch 49/50
#  - 4s - loss: 1.4742e-04 - val_loss: 4.5707e-05
# Epoch 50/50
#  - 3s - loss: 1.3309e-04 - val_loss: 4.0854e-05
# 23.152644600567992
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 4
# sells: 4
# The money our bot would have earned
# earnings: $16.15399912865405

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = True 
ma_his_window = False
ema12 = False 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 6s - loss: 0.1991 - val_loss: 0.0039
# Epoch 2/50
#  - 4s - loss: 0.0052 - val_loss: 0.0024
# Epoch 3/50
#  - 4s - loss: 0.0036 - val_loss: 0.0014
# Epoch 4/50
#  - 4s - loss: 0.0028 - val_loss: 0.0010
# Epoch 5/50
#  - 4s - loss: 0.0022 - val_loss: 3.8009e-04
# Epoch 6/50
#  - 3s - loss: 0.0018 - val_loss: 7.1735e-04
# Epoch 7/50
#  - 4s - loss: 0.0015 - val_loss: 2.0650e-04
# Epoch 8/50
#  - 4s - loss: 0.0013 - val_loss: 2.9123e-04
# Epoch 9/50
#  - 4s - loss: 0.0012 - val_loss: 1.4397e-04
# Epoch 10/50
#  - 4s - loss: 0.0011 - val_loss: 6.0328e-04
# Epoch 11/50
#  - 4s - loss: 9.8149e-04 - val_loss: 1.9714e-04
# Epoch 12/50
#  - 4s - loss: 8.7212e-04 - val_loss: 3.2094e-04
# Epoch 13/50
#  - 4s - loss: 9.0658e-04 - val_loss: 3.4310e-04
# Epoch 14/50
#  - 4s - loss: 7.5434e-04 - val_loss: 1.6972e-04
# Epoch 15/50
#  - 6s - loss: 6.6269e-04 - val_loss: 3.3381e-04
# Epoch 16/50
#  - 3s - loss: 6.6051e-04 - val_loss: 1.6755e-04
# Epoch 17/50
#  - 4s - loss: 5.8759e-04 - val_loss: 1.4732e-04
# Epoch 18/50
#  - 4s - loss: 5.8976e-04 - val_loss: 3.0385e-04
# Epoch 19/50
#  - 5s - loss: 5.4765e-04 - val_loss: 1.3224e-04
# Epoch 20/50
#  - 4s - loss: 4.8412e-04 - val_loss: 1.6536e-04
# Epoch 21/50
#  - 4s - loss: 4.9018e-04 - val_loss: 1.3008e-04
# Epoch 22/50
#  - 4s - loss: 4.4848e-04 - val_loss: 1.3065e-04
# Epoch 23/50
#  - 4s - loss: 4.2416e-04 - val_loss: 1.3096e-04
# Epoch 24/50
#  - 4s - loss: 4.0527e-04 - val_loss: 3.0856e-04
# Epoch 25/50
#  - 4s - loss: 3.7400e-04 - val_loss: 1.5400e-04
# Epoch 26/50
#  - 4s - loss: 3.7022e-04 - val_loss: 3.0626e-04
# Epoch 27/50
#  - 4s - loss: 3.6694e-04 - val_loss: 3.3828e-04
# Epoch 28/50
#  - 4s - loss: 3.3952e-04 - val_loss: 2.5697e-04
# Epoch 29/50
#  - 3s - loss: 3.2708e-04 - val_loss: 1.4358e-04
# Epoch 30/50
#  - 4s - loss: 3.3377e-04 - val_loss: 1.4935e-04
# Epoch 31/50
#  - 5s - loss: 3.0345e-04 - val_loss: 1.4400e-04
# Epoch 32/50
#  - 4s - loss: 3.2224e-04 - val_loss: 1.7495e-04
# Epoch 33/50
#  - 4s - loss: 2.8878e-04 - val_loss: 1.9907e-04
# Epoch 34/50
#  - 4s - loss: 3.0773e-04 - val_loss: 1.4801e-04
# Epoch 35/50
#  - 3s - loss: 2.9540e-04 - val_loss: 2.0656e-04
# Epoch 36/50
#  - 3s - loss: 3.0957e-04 - val_loss: 2.0208e-04
# Epoch 37/50
#  - 3s - loss: 2.9722e-04 - val_loss: 1.4883e-04
# Epoch 38/50
#  - 3s - loss: 2.7784e-04 - val_loss: 1.4113e-04
# Epoch 39/50
#  - 3s - loss: 2.8967e-04 - val_loss: 2.7921e-04
# Epoch 40/50
#  - 3s - loss: 2.6520e-04 - val_loss: 1.3280e-04
# Epoch 41/50
#  - 3s - loss: 2.7887e-04 - val_loss: 1.3945e-04
# Epoch 42/50
#  - 3s - loss: 2.6936e-04 - val_loss: 1.4417e-04
# Epoch 43/50
#  - 3s - loss: 2.6861e-04 - val_loss: 1.8726e-04
# Epoch 44/50
#  - 3s - loss: 2.8843e-04 - val_loss: 1.6521e-04
# Epoch 45/50
#  - 3s - loss: 2.6005e-04 - val_loss: 1.2242e-04
# Epoch 46/50
#  - 4s - loss: 2.6518e-04 - val_loss: 1.2801e-04
# Epoch 47/50
#  - 3s - loss: 2.6549e-04 - val_loss: 2.6268e-04
# Epoch 48/50
#  - 3s - loss: 2.5721e-04 - val_loss: 5.6476e-04
# Epoch 49/50
#  - 3s - loss: 2.6377e-04 - val_loss: 1.3379e-04
# Epoch 50/50
#  - 3s - loss: 2.5309e-04 - val_loss: 1.4845e-04
# 46.92886199545524
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 15
# sells: 12
# The money our bot would have earned
# earnings: $28.995676625387816

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = True
ema12 = False 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 4s - loss: 0.0105 - val_loss: 6.9409e-04
# Epoch 2/50
#  - 4s - loss: 0.0010 - val_loss: 0.0010
# Epoch 3/50
#  - 4s - loss: 8.0265e-04 - val_loss: 6.3287e-04
# Epoch 4/50
#  - 4s - loss: 6.3586e-04 - val_loss: 2.7430e-04
# Epoch 5/50
#  - 3s - loss: 5.7094e-04 - val_loss: 5.3922e-04
# Epoch 6/50
#  - 3s - loss: 4.9218e-04 - val_loss: 2.6737e-04
# Epoch 7/50
#  - 3s - loss: 4.2157e-04 - val_loss: 5.3344e-04
# Epoch 8/50
#  - 3s - loss: 3.8576e-04 - val_loss: 5.6731e-04
# Epoch 9/50
#  - 3s - loss: 3.5605e-04 - val_loss: 2.7151e-04
# Epoch 10/50
#  - 3s - loss: 3.4687e-04 - val_loss: 2.4135e-04
# Epoch 11/50
#  - 3s - loss: 3.2942e-04 - val_loss: 3.0690e-04
# Epoch 12/50
#  - 3s - loss: 3.0626e-04 - val_loss: 2.8132e-04
# Epoch 13/50
#  - 3s - loss: 3.0331e-04 - val_loss: 2.4839e-04
# Epoch 14/50
#  - 3s - loss: 3.0817e-04 - val_loss: 1.1732e-04
# Epoch 15/50
#  - 3s - loss: 3.0125e-04 - val_loss: 4.6002e-04
# Epoch 16/50
#  - 3s - loss: 2.9200e-04 - val_loss: 1.4884e-04
# Epoch 17/50
#  - 3s - loss: 2.6237e-04 - val_loss: 1.1816e-04
# Epoch 18/50
#  - 3s - loss: 2.6707e-04 - val_loss: 1.4894e-04
# Epoch 19/50
#  - 3s - loss: 2.6939e-04 - val_loss: 2.3175e-04
# Epoch 20/50
#  - 3s - loss: 2.5441e-04 - val_loss: 1.4073e-04
# Epoch 21/50
#  - 3s - loss: 2.6426e-04 - val_loss: 2.3436e-04
# Epoch 22/50
#  - 3s - loss: 2.6769e-04 - val_loss: 1.5633e-04
# Epoch 23/50
#  - 3s - loss: 2.4845e-04 - val_loss: 1.1740e-04
# Epoch 24/50
#  - 3s - loss: 2.3405e-04 - val_loss: 1.6205e-04
# Epoch 25/50
#  - 3s - loss: 2.6704e-04 - val_loss: 1.0566e-04
# Epoch 26/50
#  - 3s - loss: 2.4470e-04 - val_loss: 1.3173e-04
# Epoch 27/50
#  - 3s - loss: 2.4635e-04 - val_loss: 4.9856e-04
# Epoch 28/50
#  - 3s - loss: 2.5032e-04 - val_loss: 3.2194e-04
# Epoch 29/50
#  - 3s - loss: 2.4589e-04 - val_loss: 1.0146e-04
# Epoch 30/50
#  - 3s - loss: 2.2776e-04 - val_loss: 1.2177e-04
# Epoch 31/50
#  - 3s - loss: 2.7085e-04 - val_loss: 1.4515e-04
# Epoch 32/50
#  - 3s - loss: 2.3385e-04 - val_loss: 9.1423e-05
# Epoch 33/50
#  - 3s - loss: 2.3598e-04 - val_loss: 1.1293e-04
# Epoch 34/50
#  - 3s - loss: 2.4380e-04 - val_loss: 2.3847e-04
# Epoch 35/50
#  - 3s - loss: 2.2210e-04 - val_loss: 2.2048e-04
# Epoch 36/50
#  - 3s - loss: 2.4482e-04 - val_loss: 1.0320e-04
# Epoch 37/50
#  - 4s - loss: 2.1951e-04 - val_loss: 1.4513e-04
# Epoch 38/50
#  - 3s - loss: 2.4029e-04 - val_loss: 3.6486e-04
# Epoch 39/50
#  - 3s - loss: 2.4986e-04 - val_loss: 1.4630e-04
# Epoch 40/50
#  - 3s - loss: 2.2096e-04 - val_loss: 9.9933e-05
# Epoch 41/50
#  - 3s - loss: 2.4100e-04 - val_loss: 3.1512e-04
# Epoch 42/50
#  - 3s - loss: 2.4573e-04 - val_loss: 8.6652e-05
# Epoch 43/50
#  - 3s - loss: 2.2019e-04 - val_loss: 1.4431e-04
# Epoch 44/50
#  - 3s - loss: 2.2812e-04 - val_loss: 2.5976e-04
# Epoch 45/50
#  - 3s - loss: 2.3081e-04 - val_loss: 7.9176e-05
# Epoch 46/50
#  - 3s - loss: 2.2535e-04 - val_loss: 8.5243e-05
# Epoch 47/50
#  - 3s - loss: 2.2325e-04 - val_loss: 1.1773e-04
# Epoch 48/50
#  - 3s - loss: 2.2433e-04 - val_loss: 1.3756e-04
# Epoch 49/50
#  - 3s - loss: 1.9981e-04 - val_loss: 9.5630e-05
# Epoch 50/50
#  - 3s - loss: 2.0964e-04 - val_loss: 9.8196e-05
# 11.446989412894483
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 387
# sells: 62
# The money our bot would have earned
# earnings: $1112.5585306983667

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = False
ema12 = True 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 4s - loss: 0.3816 - val_loss: 0.0070
# Epoch 2/50
#  - 4s - loss: 0.0079 - val_loss: 0.0027
# Epoch 3/50
#  - 4s - loss: 0.0060 - val_loss: 0.0012
# Epoch 4/50
#  - 4s - loss: 0.0048 - val_loss: 0.0016
# Epoch 5/50
#  - 3s - loss: 0.0040 - val_loss: 7.8677e-04
# Epoch 6/50
#  - 3s - loss: 0.0034 - val_loss: 0.0028
# Epoch 7/50
#  - 3s - loss: 0.0033 - val_loss: 3.8117e-04
# Epoch 8/50
#  - 3s - loss: 0.0026 - val_loss: 3.9694e-04
# Epoch 9/50
#  - 3s - loss: 0.0024 - val_loss: 5.7882e-04
# Epoch 10/50
#  - 3s - loss: 0.0021 - val_loss: 8.9877e-04
# Epoch 11/50
#  - 3s - loss: 0.0019 - val_loss: 3.9685e-04
# Epoch 12/50
#  - 3s - loss: 0.0016 - val_loss: 5.0715e-04
# Epoch 13/50
#  - 3s - loss: 0.0015 - val_loss: 3.3680e-04
# Epoch 14/50
#  - 3s - loss: 0.0013 - val_loss: 2.9678e-04
# Epoch 15/50
#  - 3s - loss: 0.0012 - val_loss: 1.9494e-04
# Epoch 16/50
#  - 3s - loss: 0.0011 - val_loss: 7.4631e-04
# Epoch 17/50
#  - 3s - loss: 0.0010 - val_loss: 3.1039e-04
# Epoch 18/50
#  - 3s - loss: 9.1044e-04 - val_loss: 6.5318e-04
# Epoch 19/50
#  - 3s - loss: 8.0874e-04 - val_loss: 2.0228e-04
# Epoch 20/50
#  - 3s - loss: 7.8591e-04 - val_loss: 1.9789e-04
# Epoch 21/50
#  - 3s - loss: 6.9221e-04 - val_loss: 5.5197e-04
# Epoch 22/50
#  - 3s - loss: 7.1252e-04 - val_loss: 5.7311e-04
# Epoch 23/50
#  - 3s - loss: 6.4424e-04 - val_loss: 5.9709e-04
# Epoch 24/50
#  - 3s - loss: 6.1896e-04 - val_loss: 7.5085e-04
# Epoch 25/50
#  - 3s - loss: 5.3509e-04 - val_loss: 3.1854e-04
# Epoch 26/50
#  - 3s - loss: 5.1504e-04 - val_loss: 1.8121e-04
# Epoch 27/50
#  - 3s - loss: 5.2415e-04 - val_loss: 3.4957e-04
# Epoch 28/50
#  - 4s - loss: 4.9718e-04 - val_loss: 4.2672e-04
# Epoch 29/50
#  - 3s - loss: 4.3003e-04 - val_loss: 2.4109e-04
# Epoch 30/50
#  - 3s - loss: 4.3736e-04 - val_loss: 1.7694e-04
# Epoch 31/50
#  - 3s - loss: 4.1554e-04 - val_loss: 1.7902e-04
# Epoch 32/50
#  - 3s - loss: 3.8537e-04 - val_loss: 3.6827e-04
# Epoch 33/50
#  - 3s - loss: 4.0603e-04 - val_loss: 1.8016e-04
# Epoch 34/50
#  - 3s - loss: 3.4311e-04 - val_loss: 2.0674e-04
# Epoch 35/50
#  - 3s - loss: 3.3242e-04 - val_loss: 2.2815e-04
# Epoch 36/50
#  - 3s - loss: 3.5890e-04 - val_loss: 1.3207e-04
# Epoch 37/50
#  - 3s - loss: 3.1288e-04 - val_loss: 1.3386e-04
# Epoch 38/50
#  - 3s - loss: 3.1015e-04 - val_loss: 1.6992e-04
# Epoch 39/50
#  - 3s - loss: 3.0850e-04 - val_loss: 1.8635e-04
# Epoch 40/50
#  - 3s - loss: 3.0593e-04 - val_loss: 1.5218e-04
# Epoch 41/50
#  - 3s - loss: 2.7759e-04 - val_loss: 1.6263e-04
# Epoch 42/50
#  - 3s - loss: 2.8898e-04 - val_loss: 1.2999e-04
# Epoch 43/50
#  - 3s - loss: 2.8347e-04 - val_loss: 1.4379e-04
# Epoch 44/50
#  - 3s - loss: 2.7485e-04 - val_loss: 2.0566e-04
# Epoch 45/50
#  - 3s - loss: 2.7390e-04 - val_loss: 1.6186e-04
# Epoch 46/50
#  - 3s - loss: 2.6785e-04 - val_loss: 1.2025e-04
# Epoch 47/50
#  - 3s - loss: 2.6262e-04 - val_loss: 3.2564e-04
# Epoch 48/50
#  - 3s - loss: 2.6499e-04 - val_loss: 1.8279e-04
# Epoch 49/50
#  - 3s - loss: 2.4512e-04 - val_loss: 2.7073e-04
# Epoch 50/50
#  - 3s - loss: 2.5113e-04 - val_loss: 1.6208e-04
# 18.824530386085154
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 142
# sells: 61
# The money our bot would have earned
# earnings: $278.6062709908183

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = False
ema12 = False 
ema26 = True 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 4s - loss: 0.0163 - val_loss: 3.2988e-04
# Epoch 2/50
#  - 4s - loss: 0.0011 - val_loss: 2.0861e-04
# Epoch 3/50
#  - 4s - loss: 9.0687e-04 - val_loss: 2.4740e-04
# Epoch 4/50
#  - 4s - loss: 7.4627e-04 - val_loss: 2.9087e-04
# Epoch 5/50
#  - 4s - loss: 6.6903e-04 - val_loss: 1.5968e-04
# Epoch 6/50
#  - 3s - loss: 5.3710e-04 - val_loss: 3.0399e-04
# Epoch 7/50
#  - 4s - loss: 4.8740e-04 - val_loss: 5.6207e-04
# Epoch 8/50
#  - 4s - loss: 4.3685e-04 - val_loss: 1.4084e-04
# Epoch 9/50
#  - 4s - loss: 4.3136e-04 - val_loss: 6.6483e-04
# Epoch 10/50
#  - 4s - loss: 3.9391e-04 - val_loss: 4.0123e-04
# Epoch 11/50
#  - 4s - loss: 3.7405e-04 - val_loss: 1.3328e-04
# Epoch 12/50
#  - 3s - loss: 3.6497e-04 - val_loss: 1.5411e-04
# Epoch 13/50
#  - 3s - loss: 3.5422e-04 - val_loss: 1.6111e-04
# Epoch 14/50
#  - 4s - loss: 3.3064e-04 - val_loss: 3.1989e-04
# Epoch 15/50
#  - 4s - loss: 3.4530e-04 - val_loss: 2.9469e-04
# Epoch 16/50
#  - 4s - loss: 3.5898e-04 - val_loss: 1.3778e-04
# Epoch 17/50
#  - 5s - loss: 3.1304e-04 - val_loss: 1.5038e-04
# Epoch 18/50
#  - 6s - loss: 3.2402e-04 - val_loss: 2.1474e-04
# Epoch 19/50
#  - 4s - loss: 3.1078e-04 - val_loss: 1.3836e-04
# Epoch 20/50
#  - 3s - loss: 2.9822e-04 - val_loss: 1.3267e-04
# Epoch 21/50
#  - 3s - loss: 3.2781e-04 - val_loss: 1.9583e-04
# Epoch 22/50
#  - 3s - loss: 3.0654e-04 - val_loss: 1.2657e-04
# Epoch 23/50
#  - 3s - loss: 2.9336e-04 - val_loss: 1.4328e-04
# Epoch 24/50
#  - 3s - loss: 2.8590e-04 - val_loss: 1.1369e-04
# Epoch 25/50
#  - 3s - loss: 2.7675e-04 - val_loss: 2.2246e-04
# Epoch 26/50
#  - 3s - loss: 2.9377e-04 - val_loss: 2.7992e-04
# Epoch 27/50
#  - 3s - loss: 2.8434e-04 - val_loss: 1.1772e-04
# Epoch 28/50
#  - 3s - loss: 2.7443e-04 - val_loss: 2.1170e-04
# Epoch 29/50
#  - 3s - loss: 2.7882e-04 - val_loss: 2.1195e-04
# Epoch 30/50
#  - 3s - loss: 2.7206e-04 - val_loss: 4.1325e-04
# Epoch 31/50
#  - 3s - loss: 2.9090e-04 - val_loss: 1.6348e-04
# Epoch 32/50
#  - 3s - loss: 2.6922e-04 - val_loss: 1.3455e-04
# Epoch 33/50
#  - 3s - loss: 2.6574e-04 - val_loss: 1.5966e-04
# Epoch 34/50
#  - 3s - loss: 2.7469e-04 - val_loss: 9.8923e-05
# Epoch 35/50
#  - 3s - loss: 2.4710e-04 - val_loss: 1.0488e-04
# Epoch 36/50
#  - 3s - loss: 2.3951e-04 - val_loss: 1.4561e-04
# Epoch 37/50
#  - 3s - loss: 2.7441e-04 - val_loss: 1.3289e-04
# Epoch 38/50
#  - 3s - loss: 2.4985e-04 - val_loss: 1.2918e-04
# Epoch 39/50
#  - 3s - loss: 2.5966e-04 - val_loss: 9.9311e-05
# Epoch 40/50
#  - 3s - loss: 2.4844e-04 - val_loss: 1.3082e-04
# Epoch 41/50
#  - 3s - loss: 2.4335e-04 - val_loss: 1.0022e-04
# Epoch 42/50
#  - 3s - loss: 2.5529e-04 - val_loss: 8.8852e-05
# Epoch 43/50
#  - 3s - loss: 2.5266e-04 - val_loss: 2.4642e-04
# Epoch 44/50
#  - 3s - loss: 2.4088e-04 - val_loss: 1.4847e-04
# Epoch 45/50
#  - 3s - loss: 2.4597e-04 - val_loss: 1.7795e-04
# Epoch 46/50
#  - 3s - loss: 2.4341e-04 - val_loss: 1.7540e-04
# Epoch 47/50
#  - 3s - loss: 2.3488e-04 - val_loss: 2.0902e-04
# Epoch 48/50
#  - 4s - loss: 2.5201e-04 - val_loss: 1.3507e-04
# Epoch 49/50
#  - 5s - loss: 2.4903e-04 - val_loss: 1.1548e-04
# Epoch 50/50
#  - 5s - loss: 2.2363e-04 - val_loss: 2.3122e-04
# 36.27725550145657
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 8
# sells: 8
# The money our bot would have earned
# earnings: $20.013380846771085

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = False
ema12 = False 
ema26 = False 
mac = True 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 5s - loss: 0.0231 - val_loss: 0.0014
# Epoch 2/50
#  - 4s - loss: 0.0014 - val_loss: 5.9877e-04
# Epoch 3/50
#  - 4s - loss: 9.0118e-04 - val_loss: 7.7601e-04
# Epoch 4/50
#  - 4s - loss: 6.6638e-04 - val_loss: 7.5511e-04
# Epoch 5/50
#  - 4s - loss: 5.0388e-04 - val_loss: 7.1928e-04
# Epoch 6/50
#  - 4s - loss: 4.2976e-04 - val_loss: 2.9013e-04
# Epoch 7/50
#  - 5s - loss: 4.0335e-04 - val_loss: 5.7032e-04
# Epoch 8/50
#  - 4s - loss: 4.4451e-04 - val_loss: 2.2306e-04
# Epoch 9/50
#  - 4s - loss: 3.7977e-04 - val_loss: 1.8700e-04
# Epoch 10/50
#  - 4s - loss: 4.0128e-04 - val_loss: 3.3379e-04
# Epoch 11/50
#  - 4s - loss: 3.5466e-04 - val_loss: 2.3285e-04
# Epoch 12/50
#  - 5s - loss: 3.5425e-04 - val_loss: 2.4404e-04
# Epoch 13/50
#  - 4s - loss: 3.3404e-04 - val_loss: 1.5073e-04
# Epoch 14/50
#  - 4s - loss: 3.3033e-04 - val_loss: 4.3801e-04
# Epoch 15/50
#  - 4s - loss: 3.0391e-04 - val_loss: 1.9942e-04
# Epoch 16/50
#  - 4s - loss: 3.1139e-04 - val_loss: 2.6647e-04
# Epoch 17/50
#  - 4s - loss: 3.0254e-04 - val_loss: 2.1607e-04
# Epoch 18/50
#  - 5s - loss: 2.9728e-04 - val_loss: 1.4813e-04
# Epoch 19/50
#  - 4s - loss: 2.7655e-04 - val_loss: 2.1468e-04
# Epoch 20/50
#  - 5s - loss: 2.8537e-04 - val_loss: 1.2274e-04
# Epoch 21/50
#  - 5s - loss: 2.9489e-04 - val_loss: 2.3689e-04
# Epoch 22/50
#  - 4s - loss: 2.8980e-04 - val_loss: 2.1162e-04
# Epoch 23/50
#  - 4s - loss: 2.8022e-04 - val_loss: 1.8413e-04
# Epoch 24/50
#  - 4s - loss: 2.7565e-04 - val_loss: 1.2435e-04
# Epoch 25/50
#  - 4s - loss: 2.6378e-04 - val_loss: 1.1644e-04
# Epoch 26/50
#  - 5s - loss: 2.6660e-04 - val_loss: 1.1152e-04
# Epoch 27/50
#  - 4s - loss: 2.5542e-04 - val_loss: 1.2353e-04
# Epoch 28/50
#  - 3s - loss: 2.6948e-04 - val_loss: 1.5497e-04
# Epoch 29/50
#  - 3s - loss: 2.5089e-04 - val_loss: 1.5852e-04
# Epoch 30/50
#  - 4s - loss: 2.7622e-04 - val_loss: 6.3120e-04
# Epoch 31/50
#  - 3s - loss: 2.8028e-04 - val_loss: 1.0868e-04
# Epoch 32/50
#  - 3s - loss: 2.6006e-04 - val_loss: 1.2504e-04
# Epoch 33/50
#  - 4s - loss: 2.5219e-04 - val_loss: 1.5714e-04
# Epoch 34/50
#  - 4s - loss: 2.6383e-04 - val_loss: 5.2994e-04
# Epoch 35/50
#  - 4s - loss: 2.6772e-04 - val_loss: 1.2959e-04
# Epoch 36/50
#  - 5s - loss: 2.4976e-04 - val_loss: 1.1264e-04
# Epoch 37/50
#  - 4s - loss: 2.5205e-04 - val_loss: 2.9973e-04
# Epoch 38/50
#  - 4s - loss: 2.4852e-04 - val_loss: 1.1345e-04
# Epoch 39/50
#  - 4s - loss: 2.3485e-04 - val_loss: 9.9449e-05
# Epoch 40/50
#  - 4s - loss: 2.3156e-04 - val_loss: 9.9026e-05
# Epoch 41/50
#  - 4s - loss: 2.4253e-04 - val_loss: 9.4707e-05
# Epoch 42/50
#  - 5s - loss: 2.2900e-04 - val_loss: 1.0354e-04
# Epoch 43/50
#  - 4s - loss: 2.2334e-04 - val_loss: 1.5479e-04
# Epoch 44/50
#  - 4s - loss: 2.1978e-04 - val_loss: 9.7228e-05
# Epoch 45/50
#  - 4s - loss: 2.3335e-04 - val_loss: 1.0736e-04
# Epoch 46/50
#  - 4s - loss: 2.4273e-04 - val_loss: 5.5773e-04
# Epoch 47/50
#  - 4s - loss: 2.5662e-04 - val_loss: 1.0199e-04
# Epoch 48/50
#  - 4s - loss: 2.3778e-04 - val_loss: 1.0095e-04
# Epoch 49/50
#  - 4s - loss: 2.2903e-04 - val_loss: 1.0072e-04
# Epoch 50/50
#  - 5s - loss: 2.1536e-04 - val_loss: 9.6515e-05
# 13.510059817208662
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 99
# sells: 60
# The money our bot would have earned
# earnings: $175.7607931220544

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = False
ema12 = False 
ema26 = False 
mac = False 
ten_day_momentum = True
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 5s - loss: 0.0046 - val_loss: 3.0059e-04
# Epoch 2/50
#  - 4s - loss: 0.0010 - val_loss: 2.7559e-04
# Epoch 3/50
#  - 4s - loss: 7.1131e-04 - val_loss: 9.2255e-04
# Epoch 4/50
#  - 4s - loss: 6.0238e-04 - val_loss: 3.9746e-04
# Epoch 5/50
#  - 5s - loss: 4.9565e-04 - val_loss: 1.9919e-04
# Epoch 6/50
#  - 5s - loss: 4.2715e-04 - val_loss: 1.9583e-04
# Epoch 7/50
#  - 4s - loss: 4.0822e-04 - val_loss: 2.2472e-04
# Epoch 8/50
#  - 3s - loss: 3.6322e-04 - val_loss: 3.5750e-04
# Epoch 9/50
#  - 4s - loss: 3.7686e-04 - val_loss: 7.9703e-04
# Epoch 10/50
#  - 4s - loss: 3.6028e-04 - val_loss: 3.3593e-04
# Epoch 11/50
#  - 4s - loss: 3.1481e-04 - val_loss: 3.3284e-04
# Epoch 12/50
#  - 4s - loss: 3.2439e-04 - val_loss: 1.5670e-04
# Epoch 13/50
#  - 4s - loss: 3.0492e-04 - val_loss: 4.2335e-04
# Epoch 14/50
#  - 4s - loss: 2.9648e-04 - val_loss: 2.0939e-04
# Epoch 15/50
#  - 4s - loss: 2.9382e-04 - val_loss: 1.5847e-04
# Epoch 16/50
#  - 4s - loss: 2.6151e-04 - val_loss: 3.6156e-04
# Epoch 17/50
#  - 3s - loss: 2.7262e-04 - val_loss: 4.9161e-04
# Epoch 18/50
#  - 3s - loss: 2.6197e-04 - val_loss: 1.4865e-04
# Epoch 19/50
#  - 4s - loss: 2.8316e-04 - val_loss: 1.2610e-04
# Epoch 20/50
#  - 4s - loss: 2.7442e-04 - val_loss: 1.2908e-04
# Epoch 21/50
#  - 3s - loss: 2.7069e-04 - val_loss: 1.5798e-04
# Epoch 22/50
#  - 5s - loss: 2.9202e-04 - val_loss: 3.6298e-04
# Epoch 23/50
#  - 4s - loss: 2.6565e-04 - val_loss: 2.6219e-04
# Epoch 24/50
#  - 4s - loss: 2.6880e-04 - val_loss: 4.4803e-04
# Epoch 25/50
#  - 3s - loss: 2.5443e-04 - val_loss: 3.1026e-04
# Epoch 26/50
#  - 3s - loss: 2.6140e-04 - val_loss: 1.1014e-04
# Epoch 27/50
#  - 4s - loss: 2.6050e-04 - val_loss: 1.2623e-04
# Epoch 28/50
#  - 3s - loss: 2.6866e-04 - val_loss: 1.5302e-04
# Epoch 29/50
#  - 3s - loss: 2.4460e-04 - val_loss: 6.2195e-04
# Epoch 30/50
#  - 3s - loss: 2.7077e-04 - val_loss: 1.0373e-04
# Epoch 31/50
#  - 3s - loss: 2.5229e-04 - val_loss: 1.4144e-04
# Epoch 32/50
#  - 3s - loss: 2.4342e-04 - val_loss: 9.4324e-05
# Epoch 33/50
#  - 3s - loss: 2.3217e-04 - val_loss: 1.3219e-04
# Epoch 34/50
#  - 4s - loss: 2.3263e-04 - val_loss: 1.2293e-04
# Epoch 35/50
#  - 4s - loss: 2.5166e-04 - val_loss: 1.1411e-04
# Epoch 36/50
#  - 4s - loss: 2.3297e-04 - val_loss: 9.1015e-05
# Epoch 37/50
#  - 5s - loss: 2.2910e-04 - val_loss: 1.0972e-04
# Epoch 38/50
#  - 4s - loss: 2.2081e-04 - val_loss: 1.9573e-04
# Epoch 39/50
#  - 3s - loss: 2.2348e-04 - val_loss: 8.0950e-05
# Epoch 40/50
#  - 3s - loss: 2.2720e-04 - val_loss: 1.0841e-04
# Epoch 41/50
#  - 4s - loss: 2.3294e-04 - val_loss: 2.5843e-04
# Epoch 42/50
#  - 4s - loss: 2.3014e-04 - val_loss: 1.9912e-04
# Epoch 43/50
#  - 4s - loss: 2.2328e-04 - val_loss: 9.7028e-05
# Epoch 44/50
#  - 3s - loss: 2.2809e-04 - val_loss: 3.2781e-04
# Epoch 45/50
#  - 3s - loss: 2.4213e-04 - val_loss: 1.9325e-04
# Epoch 46/50
#  - 3s - loss: 2.1845e-04 - val_loss: 1.0988e-04
# Epoch 47/50
#  - 3s - loss: 2.2631e-04 - val_loss: 7.9236e-05
# Epoch 48/50
#  - 4s - loss: 2.2773e-04 - val_loss: 7.5355e-05
# Epoch 49/50
#  - 3s - loss: 2.2232e-04 - val_loss: 1.6559e-04
# Epoch 50/50
#  - 4s - loss: 2.2499e-04 - val_loss: 2.4709e-04
# 14.590494988401181
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 455
# sells: 31
# The money our bot would have earned
# earnings: $1753.7521272084496

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = False
ema12 = False 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = True 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 5s - loss: 0.0059 - val_loss: 4.5766e-04
# Epoch 2/50
#  - 4s - loss: 0.0010 - val_loss: 5.1756e-04
# Epoch 3/50
#  - 4s - loss: 6.7125e-04 - val_loss: 2.9319e-04
# Epoch 4/50
#  - 4s - loss: 5.2491e-04 - val_loss: 3.1731e-04
# Epoch 5/50
#  - 4s - loss: 4.7073e-04 - val_loss: 1.9854e-04
# Epoch 6/50
#  - 4s - loss: 3.9172e-04 - val_loss: 2.9921e-04
# Epoch 7/50
#  - 4s - loss: 3.6311e-04 - val_loss: 1.4574e-04
# Epoch 8/50
#  - 4s - loss: 3.2865e-04 - val_loss: 1.4517e-04
# Epoch 9/50
#  - 4s - loss: 3.1783e-04 - val_loss: 2.0292e-04
# Epoch 10/50
#  - 4s - loss: 3.0916e-04 - val_loss: 1.4898e-04
# Epoch 11/50
#  - 4s - loss: 2.9671e-04 - val_loss: 4.4270e-04
# Epoch 12/50
#  - 4s - loss: 3.4325e-04 - val_loss: 3.3751e-04
# Epoch 13/50
#  - 5s - loss: 2.8134e-04 - val_loss: 2.4697e-04
# Epoch 14/50
#  - 4s - loss: 2.7072e-04 - val_loss: 1.4474e-04
# Epoch 15/50
#  - 4s - loss: 2.6405e-04 - val_loss: 1.2137e-04
# Epoch 16/50
#  - 4s - loss: 2.6610e-04 - val_loss: 2.0101e-04
# Epoch 17/50
#  - 3s - loss: 2.5844e-04 - val_loss: 6.4556e-04
# Epoch 18/50
#  - 4s - loss: 2.7887e-04 - val_loss: 6.3362e-04
# Epoch 19/50
#  - 4s - loss: 2.7577e-04 - val_loss: 1.4860e-04
# Epoch 20/50
#  - 4s - loss: 2.5125e-04 - val_loss: 2.1700e-04
# Epoch 21/50
#  - 4s - loss: 2.5184e-04 - val_loss: 1.2557e-04
# Epoch 22/50
#  - 4s - loss: 2.5537e-04 - val_loss: 1.0429e-04
# Epoch 23/50
#  - 4s - loss: 2.4930e-04 - val_loss: 1.5361e-04
# Epoch 24/50
#  - 4s - loss: 2.3243e-04 - val_loss: 1.3031e-04
# Epoch 25/50
#  - 4s - loss: 2.6504e-04 - val_loss: 2.9718e-04
# Epoch 26/50
#  - 3s - loss: 2.4566e-04 - val_loss: 1.3845e-04
# Epoch 27/50
#  - 4s - loss: 2.3848e-04 - val_loss: 1.0772e-04
# Epoch 28/50
#  - 4s - loss: 2.4629e-04 - val_loss: 9.2962e-05
# Epoch 29/50
#  - 5s - loss: 2.5046e-04 - val_loss: 1.1948e-04
# Epoch 30/50
#  - 4s - loss: 2.4627e-04 - val_loss: 1.1267e-04
# Epoch 31/50
#  - 4s - loss: 2.4038e-04 - val_loss: 1.4697e-04
# Epoch 32/50
#  - 5s - loss: 2.3541e-04 - val_loss: 9.1735e-05
# Epoch 33/50
#  - 4s - loss: 2.4214e-04 - val_loss: 1.9383e-04
# Epoch 34/50
#  - 4s - loss: 2.4348e-04 - val_loss: 9.8962e-05
# Epoch 35/50
#  - 4s - loss: 2.2398e-04 - val_loss: 2.1991e-04
# Epoch 36/50
#  - 4s - loss: 2.5113e-04 - val_loss: 1.7862e-04
# Epoch 37/50
#  - 4s - loss: 2.1969e-04 - val_loss: 8.5302e-05
# Epoch 38/50
#  - 4s - loss: 2.3124e-04 - val_loss: 8.1600e-05
# Epoch 39/50
#  - 3s - loss: 2.1463e-04 - val_loss: 1.2246e-04
# Epoch 40/50
#  - 4s - loss: 2.1614e-04 - val_loss: 8.6335e-05
# Epoch 41/50
#  - 4s - loss: 2.0767e-04 - val_loss: 9.4643e-05
# Epoch 42/50
#  - 3s - loss: 2.2043e-04 - val_loss: 9.6297e-05
# Epoch 43/50
#  - 4s - loss: 2.1273e-04 - val_loss: 1.5151e-04
# Epoch 44/50
#  - 4s - loss: 2.2228e-04 - val_loss: 7.8040e-05
# Epoch 45/50
#  - 4s - loss: 2.3174e-04 - val_loss: 8.9843e-05
# Epoch 46/50
#  - 3s - loss: 2.1661e-04 - val_loss: 1.6713e-04
# Epoch 47/50
#  - 3s - loss: 2.1757e-04 - val_loss: 7.9854e-05
# Epoch 48/50
#  - 3s - loss: 2.1186e-04 - val_loss: 1.3290e-04
# Epoch 49/50
#  - 3s - loss: 2.0288e-04 - val_loss: 8.7424e-05
# Epoch 50/50
#  - 3s - loss: 2.2007e-04 - val_loss: 1.7700e-04
# 27.21551782988967
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 9
# sells: 9
# The money our bot would have earned
# earnings: $30.83629709698397

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = False
ema12 = False 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = True
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 4s - loss: 0.0218 - val_loss: 0.0010
# Epoch 2/50
#  - 4s - loss: 0.0011 - val_loss: 8.4971e-04
# Epoch 3/50
#  - 4s - loss: 9.7138e-04 - val_loss: 8.0867e-04
# Epoch 4/50
#  - 3s - loss: 8.0711e-04 - val_loss: 6.8886e-04
# Epoch 5/50
#  - 3s - loss: 7.1137e-04 - val_loss: 3.5838e-04
# Epoch 6/50
#  - 3s - loss: 5.8006e-04 - val_loss: 2.0195e-04
# Epoch 7/50
#  - 3s - loss: 5.4079e-04 - val_loss: 3.9124e-04
# Epoch 8/50
#  - 3s - loss: 5.0529e-04 - val_loss: 3.1611e-04
# Epoch 9/50
#  - 3s - loss: 4.5595e-04 - val_loss: 2.6013e-04
# Epoch 10/50
#  - 3s - loss: 4.0143e-04 - val_loss: 3.3361e-04
# Epoch 11/50
#  - 3s - loss: 3.9752e-04 - val_loss: 3.0663e-04
# Epoch 12/50
#  - 3s - loss: 3.9197e-04 - val_loss: 4.7577e-04
# Epoch 13/50
#  - 3s - loss: 3.9356e-04 - val_loss: 1.3645e-04
# Epoch 14/50
#  - 4s - loss: 3.2845e-04 - val_loss: 1.6229e-04
# Epoch 15/50
#  - 5s - loss: 3.3723e-04 - val_loss: 2.5885e-04
# Epoch 16/50
#  - 5s - loss: 3.2416e-04 - val_loss: 1.4377e-04
# Epoch 17/50
#  - 4s - loss: 2.8918e-04 - val_loss: 1.3478e-04
# Epoch 18/50
#  - 4s - loss: 2.9991e-04 - val_loss: 3.0982e-04
# Epoch 19/50
#  - 4s - loss: 3.0322e-04 - val_loss: 4.9275e-04
# Epoch 20/50
#  - 3s - loss: 3.0628e-04 - val_loss: 1.3186e-04
# Epoch 21/50
#  - 4s - loss: 2.7432e-04 - val_loss: 1.2473e-04
# Epoch 22/50
#  - 4s - loss: 2.8263e-04 - val_loss: 1.1489e-04
# Epoch 23/50
#  - 4s - loss: 2.7692e-04 - val_loss: 1.1995e-04
# Epoch 24/50
#  - 4s - loss: 2.7007e-04 - val_loss: 3.0917e-04
# Epoch 25/50
#  - 5s - loss: 2.8139e-04 - val_loss: 1.6509e-04
# Epoch 26/50
#  - 5s - loss: 2.7572e-04 - val_loss: 1.2085e-04
# Epoch 27/50
#  - 4s - loss: 2.7321e-04 - val_loss: 1.9583e-04
# Epoch 28/50
#  - 5s - loss: 2.7641e-04 - val_loss: 2.2214e-04
# Epoch 29/50
#  - 4s - loss: 2.6476e-04 - val_loss: 1.8335e-04
# Epoch 30/50
#  - 4s - loss: 2.6895e-04 - val_loss: 1.1422e-04
# Epoch 31/50
#  - 4s - loss: 2.4026e-04 - val_loss: 1.3478e-04
# Epoch 32/50
#  - 3s - loss: 2.4365e-04 - val_loss: 2.8326e-04
# Epoch 33/50
#  - 3s - loss: 2.5730e-04 - val_loss: 1.4666e-04
# Epoch 34/50
#  - 3s - loss: 2.5463e-04 - val_loss: 1.0351e-04
# Epoch 35/50
#  - 4s - loss: 2.6010e-04 - val_loss: 1.0974e-04
# Epoch 36/50
#  - 4s - loss: 2.5037e-04 - val_loss: 1.1258e-04
# Epoch 37/50
#  - 3s - loss: 2.5359e-04 - val_loss: 1.6101e-04
# Epoch 38/50
#  - 3s - loss: 2.4788e-04 - val_loss: 1.3898e-04
# Epoch 39/50
#  - 4s - loss: 2.5865e-04 - val_loss: 1.7403e-04
# Epoch 40/50
#  - 3s - loss: 2.6829e-04 - val_loss: 1.1059e-04
# Epoch 41/50
#  - 3s - loss: 2.3617e-04 - val_loss: 1.8485e-04
# Epoch 42/50
#  - 4s - loss: 2.4615e-04 - val_loss: 1.1759e-04
# Epoch 43/50
#  - 5s - loss: 2.4019e-04 - val_loss: 1.1246e-04
# Epoch 44/50
#  - 4s - loss: 2.3727e-04 - val_loss: 1.1017e-04
# Epoch 45/50
#  - 6s - loss: 2.5082e-04 - val_loss: 1.1936e-04
# Epoch 46/50
#  - 6s - loss: 2.4462e-04 - val_loss: 1.6165e-04
# Epoch 47/50
#  - 6s - loss: 2.6300e-04 - val_loss: 9.9772e-05
# Epoch 48/50
#  - 4s - loss: 2.2961e-04 - val_loss: 1.1126e-04
# Epoch 49/50
#  - 4s - loss: 2.6489e-04 - val_loss: 9.0535e-05
# Epoch 50/50
#  - 3s - loss: 2.3321e-04 - val_loss: 1.3001e-04
# 38.21084528409692
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 13
# sells: 11
# The money our bot would have earned
# earnings: $36.73682665891204

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = False
ema12 = False 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = True
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4032 samples, validate on 448 samples
# Epoch 1/50
#  - 5s - loss: 0.0181 - val_loss: 8.8019e-04
# Epoch 2/50
#  - 4s - loss: 0.0013 - val_loss: 3.6749e-04
# Epoch 3/50
#  - 4s - loss: 8.7600e-04 - val_loss: 4.0033e-04
# Epoch 4/50
#  - 4s - loss: 7.0037e-04 - val_loss: 2.2088e-04
# Epoch 5/50
#  - 4s - loss: 5.9817e-04 - val_loss: 2.0588e-04
# Epoch 6/50
#  - 6s - loss: 4.7829e-04 - val_loss: 1.9826e-04
# Epoch 7/50
#  - 4s - loss: 4.3707e-04 - val_loss: 3.8854e-04
# Epoch 8/50
#  - 5s - loss: 4.0913e-04 - val_loss: 3.3387e-04
# Epoch 9/50
#  - 7s - loss: 3.9821e-04 - val_loss: 1.8616e-04
# Epoch 10/50
#  - 5s - loss: 3.7883e-04 - val_loss: 1.9054e-04
# Epoch 11/50
#  - 4s - loss: 3.6309e-04 - val_loss: 1.6795e-04
# Epoch 12/50
#  - 4s - loss: 3.6082e-04 - val_loss: 3.8172e-04
# Epoch 13/50
#  - 4s - loss: 3.3041e-04 - val_loss: 4.3142e-04
# Epoch 14/50
#  - 4s - loss: 3.0424e-04 - val_loss: 1.6900e-04
# Epoch 15/50
#  - 4s - loss: 3.1291e-04 - val_loss: 1.7710e-04
# Epoch 16/50
#  - 4s - loss: 3.1158e-04 - val_loss: 1.6167e-04
# Epoch 17/50
#  - 4s - loss: 2.8803e-04 - val_loss: 2.9116e-04
# Epoch 18/50
#  - 4s - loss: 2.8165e-04 - val_loss: 1.2224e-04
# Epoch 19/50
#  - 4s - loss: 2.8171e-04 - val_loss: 3.5141e-04
# Epoch 20/50
#  - 4s - loss: 2.8571e-04 - val_loss: 1.2104e-04
# Epoch 21/50
#  - 4s - loss: 2.8547e-04 - val_loss: 2.5647e-04
# Epoch 22/50
#  - 5s - loss: 2.6756e-04 - val_loss: 1.3652e-04
# Epoch 23/50
#  - 4s - loss: 2.6167e-04 - val_loss: 1.0483e-04
# Epoch 24/50
#  - 4s - loss: 2.8405e-04 - val_loss: 1.6951e-04
# Epoch 25/50
#  - 5s - loss: 2.5885e-04 - val_loss: 1.4018e-04
# Epoch 26/50
#  - 4s - loss: 2.6467e-04 - val_loss: 1.2150e-04
# Epoch 27/50
#  - 4s - loss: 2.5987e-04 - val_loss: 9.5820e-05
# Epoch 28/50
#  - 4s - loss: 2.4485e-04 - val_loss: 1.3108e-04
# Epoch 29/50
#  - 4s - loss: 2.4167e-04 - val_loss: 1.0340e-04
# Epoch 30/50
#  - 5s - loss: 2.4977e-04 - val_loss: 2.7841e-04
# Epoch 31/50
#  - 5s - loss: 2.5567e-04 - val_loss: 1.0605e-04
# Epoch 32/50
#  - 4s - loss: 2.4475e-04 - val_loss: 1.4744e-04
# Epoch 33/50
#  - 4s - loss: 2.3543e-04 - val_loss: 1.0002e-04
# Epoch 34/50
#  - 4s - loss: 2.2033e-04 - val_loss: 2.0295e-04
# Epoch 35/50
#  - 4s - loss: 2.4444e-04 - val_loss: 1.3944e-04
# Epoch 36/50
#  - 4s - loss: 2.4953e-04 - val_loss: 3.5778e-04
# Epoch 37/50
#  - 4s - loss: 2.3169e-04 - val_loss: 8.6758e-05
# Epoch 38/50
#  - 3s - loss: 2.3942e-04 - val_loss: 4.1795e-04
# Epoch 39/50
#  - 4s - loss: 2.2450e-04 - val_loss: 2.6453e-04
# Epoch 40/50
#  - 4s - loss: 2.2570e-04 - val_loss: 8.6191e-05
# Epoch 41/50
#  - 4s - loss: 2.3773e-04 - val_loss: 1.1522e-04
# Epoch 42/50
#  - 4s - loss: 2.4531e-04 - val_loss: 1.0414e-04
# Epoch 43/50
#  - 5s - loss: 2.2821e-04 - val_loss: 8.1751e-05
# Epoch 44/50
#  - 4s - loss: 2.3311e-04 - val_loss: 9.3139e-05
# Epoch 45/50
#  - 4s - loss: 2.3307e-04 - val_loss: 1.0112e-04
# Epoch 46/50
#  - 4s - loss: 2.4777e-04 - val_loss: 1.0503e-04
# Epoch 47/50
#  - 4s - loss: 2.1242e-04 - val_loss: 8.3874e-05
# Epoch 48/50
#  - 4s - loss: 2.1757e-04 - val_loss: 7.5009e-05
# Epoch 49/50
#  - 4s - loss: 2.2269e-04 - val_loss: 1.7525e-04
# Epoch 50/50
#  - 4s - loss: 2.2317e-04 - val_loss: 1.0422e-04
# 18.547761832987348
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 49
# sells: 39
# The money our bot would have earned
# earnings: $104.21665660761852

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = False
ema12 = False 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 50 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = False

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 4s - loss: 0.0274 - val_loss: 0.0017
# Epoch 2/50
#  - 4s - loss: 0.0016 - val_loss: 7.1965e-04
# Epoch 3/50
#  - 4s - loss: 0.0013 - val_loss: 7.2986e-04
# Epoch 4/50
#  - 4s - loss: 0.0011 - val_loss: 4.0480e-04
# Epoch 5/50
#  - 4s - loss: 9.0176e-04 - val_loss: 5.8404e-04
# Epoch 6/50
#  - 3s - loss: 7.9940e-04 - val_loss: 4.3856e-04
# Epoch 7/50
#  - 4s - loss: 6.6882e-04 - val_loss: 3.1236e-04
# Epoch 8/50
#  - 5s - loss: 6.0677e-04 - val_loss: 2.5617e-04
# Epoch 9/50
#  - 3s - loss: 5.7166e-04 - val_loss: 2.7345e-04
# Epoch 10/50
#  - 3s - loss: 4.7824e-04 - val_loss: 6.9257e-04
# Epoch 11/50
#  - 3s - loss: 4.9909e-04 - val_loss: 2.0762e-04
# Epoch 12/50
#  - 4s - loss: 4.5567e-04 - val_loss: 2.5117e-04
# Epoch 13/50
#  - 3s - loss: 4.3434e-04 - val_loss: 3.2210e-04
# Epoch 14/50
#  - 4s - loss: 4.5167e-04 - val_loss: 3.0366e-04
# Epoch 15/50
#  - 3s - loss: 4.0952e-04 - val_loss: 2.1645e-04
# Epoch 16/50
#  - 5s - loss: 4.2406e-04 - val_loss: 4.8251e-04
# Epoch 17/50
#  - 3s - loss: 3.7151e-04 - val_loss: 1.9171e-04
# Epoch 18/50
#  - 4s - loss: 3.6311e-04 - val_loss: 2.1727e-04
# Epoch 19/50
#  - 3s - loss: 3.6322e-04 - val_loss: 1.3200e-04
# Epoch 20/50
#  - 3s - loss: 3.3036e-04 - val_loss: 1.3034e-04
# Epoch 21/50
#  - 3s - loss: 3.3647e-04 - val_loss: 3.2064e-04
# Epoch 22/50
#  - 3s - loss: 3.2023e-04 - val_loss: 1.3380e-04
# Epoch 23/50
#  - 3s - loss: 2.9249e-04 - val_loss: 2.0587e-04
# Epoch 24/50
#  - 4s - loss: 3.1185e-04 - val_loss: 2.6095e-04
# Epoch 25/50
#  - 4s - loss: 3.0856e-04 - val_loss: 4.1193e-04
# Epoch 26/50
#  - 5s - loss: 2.9810e-04 - val_loss: 2.1089e-04
# Epoch 27/50
#  - 4s - loss: 3.1134e-04 - val_loss: 1.6486e-04
# Epoch 28/50
#  - 4s - loss: 2.8322e-04 - val_loss: 1.7933e-04
# Epoch 29/50
#  - 7s - loss: 2.8112e-04 - val_loss: 1.3046e-04
# Epoch 30/50
#  - 7s - loss: 2.6842e-04 - val_loss: 1.2527e-04
# Epoch 31/50
#  - 7s - loss: 2.7981e-04 - val_loss: 3.6035e-04
# Epoch 32/50
#  - 5s - loss: 2.9839e-04 - val_loss: 5.7944e-04
# Epoch 33/50
#  - 4s - loss: 2.8299e-04 - val_loss: 1.2308e-04
# Epoch 34/50
#  - 6s - loss: 2.9369e-04 - val_loss: 1.2996e-04
# Epoch 35/50
#  - 4s - loss: 2.4430e-04 - val_loss: 1.3133e-04
# Epoch 36/50
#  - 4s - loss: 2.6326e-04 - val_loss: 3.6388e-04
# Epoch 37/50
#  - 4s - loss: 2.4583e-04 - val_loss: 1.2041e-04
# Epoch 38/50
#  - 4s - loss: 2.4772e-04 - val_loss: 1.2340e-04
# Epoch 39/50
#  - 4s - loss: 2.5156e-04 - val_loss: 3.3670e-04
# Epoch 40/50
#  - 4s - loss: 2.5346e-04 - val_loss: 1.6043e-04
# Epoch 41/50
#  - 4s - loss: 2.4548e-04 - val_loss: 3.0338e-04
# Epoch 42/50
#  - 3s - loss: 2.7239e-04 - val_loss: 2.5443e-04
# Epoch 43/50
#  - 3s - loss: 2.4835e-04 - val_loss: 1.3856e-04
# Epoch 44/50
#  - 3s - loss: 2.4262e-04 - val_loss: 2.0093e-04
# Epoch 45/50
#  - 6s - loss: 2.3848e-04 - val_loss: 1.8336e-04
# Epoch 46/50
#  - 4s - loss: 2.5491e-04 - val_loss: 1.7862e-04
# Epoch 47/50
#  - 6s - loss: 2.4128e-04 - val_loss: 2.8423e-04
# Epoch 48/50
#  - 5s - loss: 2.3828e-04 - val_loss: 1.1944e-04
# Epoch 49/50
#  - 3s - loss: 2.4541e-04 - val_loss: 4.3400e-04
# Epoch 50/50
#  - 3s - loss: 2.5793e-04 - val_loss: 1.0257e-04
# 19.842529845060092
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 160
# sells: 70
# The money our bot would have earned
# earnings: $229.65908555342224

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = False
ema12 = False 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = True

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 4s - loss: 0.0070 - val_loss: 6.2523e-04
# Epoch 2/50
#  - 4s - loss: 0.0010 - val_loss: 2.8953e-04
# Epoch 3/50
#  - 3s - loss: 7.5574e-04 - val_loss: 2.1790e-04
# Epoch 4/50
#  - 4s - loss: 6.4983e-04 - val_loss: 2.0656e-04
# Epoch 5/50
#  - 3s - loss: 5.7088e-04 - val_loss: 1.9173e-04
# Epoch 6/50
#  - 3s - loss: 4.5612e-04 - val_loss: 7.1175e-04
# Epoch 7/50
#  - 3s - loss: 4.5156e-04 - val_loss: 3.0362e-04
# Epoch 8/50
#  - 3s - loss: 4.2561e-04 - val_loss: 2.1338e-04
# Epoch 9/50
#  - 3s - loss: 4.0306e-04 - val_loss: 4.0024e-04
# Epoch 10/50
#  - 3s - loss: 3.5936e-04 - val_loss: 3.5097e-04
# Epoch 11/50
#  - 3s - loss: 3.6665e-04 - val_loss: 2.2335e-04
# Epoch 12/50
#  - 3s - loss: 3.3652e-04 - val_loss: 1.4511e-04
# Epoch 13/50
#  - 3s - loss: 3.2426e-04 - val_loss: 3.8820e-04
# Epoch 14/50
#  - 3s - loss: 3.1511e-04 - val_loss: 1.3911e-04
# Epoch 15/50
#  - 3s - loss: 2.9937e-04 - val_loss: 5.7797e-04
# Epoch 16/50
#  - 3s - loss: 3.0289e-04 - val_loss: 1.3973e-04
# Epoch 17/50
#  - 3s - loss: 3.2151e-04 - val_loss: 1.2497e-04
# Epoch 18/50
#  - 3s - loss: 2.8867e-04 - val_loss: 2.4894e-04
# Epoch 19/50
#  - 3s - loss: 2.8539e-04 - val_loss: 1.2264e-04
# Epoch 20/50
#  - 4s - loss: 2.8463e-04 - val_loss: 1.7569e-04
# Epoch 21/50
#  - 3s - loss: 3.0884e-04 - val_loss: 1.6460e-04
# Epoch 22/50
#  - 3s - loss: 2.6012e-04 - val_loss: 1.5054e-04
# Epoch 23/50
#  - 3s - loss: 2.7301e-04 - val_loss: 1.4843e-04
# Epoch 24/50
#  - 3s - loss: 2.8779e-04 - val_loss: 4.2893e-04
# Epoch 25/50
#  - 3s - loss: 2.8197e-04 - val_loss: 1.8145e-04
# Epoch 26/50
#  - 3s - loss: 2.7352e-04 - val_loss: 1.3470e-04
# Epoch 27/50
#  - 3s - loss: 2.9363e-04 - val_loss: 1.7681e-04
# Epoch 28/50
#  - 4s - loss: 2.6165e-04 - val_loss: 9.7156e-05
# Epoch 29/50
#  - 3s - loss: 2.4335e-04 - val_loss: 5.2135e-04
# Epoch 30/50
#  - 3s - loss: 2.5866e-04 - val_loss: 1.0143e-04
# Epoch 31/50
#  - 3s - loss: 2.5135e-04 - val_loss: 1.7227e-04
# Epoch 32/50
#  - 3s - loss: 2.5698e-04 - val_loss: 2.2208e-04
# Epoch 33/50
#  - 3s - loss: 2.6131e-04 - val_loss: 1.0434e-04
# Epoch 34/50
#  - 3s - loss: 2.3788e-04 - val_loss: 1.0453e-04
# Epoch 35/50
#  - 3s - loss: 2.4006e-04 - val_loss: 2.2881e-04
# Epoch 36/50
#  - 3s - loss: 2.4984e-04 - val_loss: 1.1319e-04
# Epoch 37/50
#  - 3s - loss: 2.3874e-04 - val_loss: 9.0391e-05
# Epoch 38/50
#  - 3s - loss: 2.5440e-04 - val_loss: 3.7037e-04
# Epoch 39/50
#  - 3s - loss: 2.3481e-04 - val_loss: 1.0852e-04
# Epoch 40/50
#  - 3s - loss: 2.3685e-04 - val_loss: 8.8900e-05
# Epoch 41/50
#  - 3s - loss: 2.3639e-04 - val_loss: 2.5223e-04
# Epoch 42/50
#  - 3s - loss: 2.2156e-04 - val_loss: 6.2430e-04
# Epoch 43/50
#  - 3s - loss: 2.6216e-04 - val_loss: 8.7814e-05
# Epoch 44/50
#  - 3s - loss: 2.5123e-04 - val_loss: 1.8106e-04
# Epoch 45/50
#  - 3s - loss: 2.4848e-04 - val_loss: 2.2646e-04
# Epoch 46/50
#  - 3s - loss: 2.2915e-04 - val_loss: 1.4854e-04
# Epoch 47/50
#  - 3s - loss: 2.5249e-04 - val_loss: 1.9017e-04
# Epoch 48/50
#  - 3s - loss: 2.5768e-04 - val_loss: 8.9227e-05
# Epoch 49/50
#  - 3s - loss: 2.1873e-04 - val_loss: 2.5338e-04
# Epoch 50/50
#  - 3s - loss: 2.2899e-04 - val_loss: 1.3763e-04
# 12.991567935037901
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 368
# sells: 57
# The money our bot would have earned
# earnings: $1011.7028576966728

# %%
plt.gcf().set_size_inches(22, 15, forward=True)
real = plt.plot(values_original, label='real')
pred = plt.plot(values_predicted, label='predicted')
if len(buys) > 0:
    plt.scatter(list(list(zip(*buys))[0]), list(list(zip(*buys))[1]), c='#00ff00', s=50)
if len(sells) > 0:
    plt.scatter(list(list(zip(*sells))[0]), list(list(zip(*sells))[1]), c='#ff0000', s=50)
# real = plt.plot(unscaled_y[start:end], label='real')
# pred = plt.plot(y_predicted[start:end], label='predicted')
plt.legend(['Real', 'Predicted', 'Buy', 'Sell'])
# Delete the comment to save the plot
save_string = str(widget.kwargs['x']) + '.png'
plt.savefig(save_string)
plt.show()

# %% [markdown]
# # Green and orange Models

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = False 
ma7 = False
ma21 = False 
ma_his_window = True
ema12 = True 
ema26 = False 
mac = False 
ten_day_momentum = False
upper_bands = False 
lower_bands = False
volatilty_index_feature = False
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = True

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4034 samples, validate on 449 samples
# Epoch 1/50
#  - 5s - loss: 0.0413 - val_loss: 0.0010
# Epoch 2/50
#  - 4s - loss: 0.0021 - val_loss: 9.7452e-04
# Epoch 3/50
#  - 4s - loss: 0.0016 - val_loss: 7.5583e-04
# Epoch 4/50
#  - 4s - loss: 0.0013 - val_loss: 3.8670e-04
# Epoch 5/50
#  - 4s - loss: 0.0011 - val_loss: 4.9589e-04
# Epoch 6/50
#  - 3s - loss: 8.9216e-04 - val_loss: 1.7900e-04
# Epoch 7/50
#  - 4s - loss: 7.7433e-04 - val_loss: 2.0778e-04
# Epoch 8/50
#  - 4s - loss: 7.1166e-04 - val_loss: 2.7484e-04
# Epoch 9/50
#  - 4s - loss: 6.0875e-04 - val_loss: 3.4686e-04
# Epoch 10/50
#  - 4s - loss: 6.0194e-04 - val_loss: 2.2072e-04
# Epoch 11/50
#  - 4s - loss: 5.2266e-04 - val_loss: 3.3630e-04
# Epoch 12/50
#  - 4s - loss: 4.6896e-04 - val_loss: 3.8162e-04
# Epoch 13/50
#  - 5s - loss: 4.8853e-04 - val_loss: 2.2288e-04
# Epoch 14/50
#  - 5s - loss: 4.5230e-04 - val_loss: 2.3653e-04
# Epoch 15/50
#  - 5s - loss: 4.1903e-04 - val_loss: 3.1891e-04
# Epoch 16/50
#  - 6s - loss: 3.9807e-04 - val_loss: 4.2733e-04
# Epoch 17/50
#  - 4s - loss: 4.1065e-04 - val_loss: 2.8628e-04
# Epoch 18/50
#  - 4s - loss: 3.6861e-04 - val_loss: 1.7644e-04
# Epoch 19/50
#  - 4s - loss: 3.7739e-04 - val_loss: 5.0727e-04
# Epoch 20/50
#  - 4s - loss: 3.7229e-04 - val_loss: 1.7039e-04
# Epoch 21/50
#  - 5s - loss: 3.5699e-04 - val_loss: 2.0463e-04
# Epoch 22/50
#  - 4s - loss: 3.4109e-04 - val_loss: 2.9034e-04
# Epoch 23/50
#  - 5s - loss: 3.1744e-04 - val_loss: 2.5778e-04
# Epoch 24/50
#  - 4s - loss: 3.3005e-04 - val_loss: 3.2856e-04
# Epoch 25/50
#  - 3s - loss: 3.2580e-04 - val_loss: 3.3809e-04
# Epoch 26/50
#  - 3s - loss: 3.2783e-04 - val_loss: 1.7674e-04
# Epoch 27/50
#  - 3s - loss: 3.0058e-04 - val_loss: 1.5057e-04
# Epoch 28/50
#  - 3s - loss: 3.0927e-04 - val_loss: 1.7888e-04
# Epoch 29/50
#  - 5s - loss: 3.1109e-04 - val_loss: 1.7099e-04
# Epoch 30/50
#  - 4s - loss: 2.7549e-04 - val_loss: 1.4003e-04
# Epoch 31/50
#  - 5s - loss: 2.9244e-04 - val_loss: 1.3931e-04
# Epoch 32/50
#  - 3s - loss: 2.8138e-04 - val_loss: 1.9278e-04
# Epoch 33/50
#  - 3s - loss: 2.8265e-04 - val_loss: 1.6650e-04
# Epoch 34/50
#  - 4s - loss: 2.8826e-04 - val_loss: 1.7472e-04
# Epoch 35/50
#  - 4s - loss: 2.7013e-04 - val_loss: 2.1268e-04
# Epoch 36/50
#  - 4s - loss: 2.9005e-04 - val_loss: 2.2476e-04
# Epoch 37/50
#  - 4s - loss: 3.1885e-04 - val_loss: 2.0924e-04
# Epoch 38/50
#  - 5s - loss: 2.5218e-04 - val_loss: 1.6705e-04
# Epoch 39/50
#  - 4s - loss: 2.7469e-04 - val_loss: 2.1714e-04
# Epoch 40/50
#  - 4s - loss: 2.7351e-04 - val_loss: 2.5958e-04
# Epoch 41/50
#  - 3s - loss: 2.6206e-04 - val_loss: 4.9217e-04
# Epoch 42/50
#  - 4s - loss: 2.7241e-04 - val_loss: 1.6972e-04
# Epoch 43/50
#  - 4s - loss: 2.5979e-04 - val_loss: 1.2465e-04
# Epoch 44/50
#  - 4s - loss: 2.5234e-04 - val_loss: 1.6951e-04
# Epoch 45/50
#  - 3s - loss: 3.0140e-04 - val_loss: 1.0942e-04
# Epoch 46/50
#  - 4s - loss: 2.5746e-04 - val_loss: 1.3206e-04
# Epoch 47/50
#  - 5s - loss: 2.6062e-04 - val_loss: 1.0948e-04
# Epoch 48/50
#  - 4s - loss: 2.4904e-04 - val_loss: 2.8942e-04
# Epoch 49/50
#  - 4s - loss: 2.2218e-04 - val_loss: 1.9799e-04
# Epoch 50/50
#  - 6s - loss: 2.5130e-04 - val_loss: 9.0504e-05
# 10.002246400102724
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 225
# sells: 98
# The money our bot would have earned
# earnings: $386.47568601161225

# %%
plt.gcf().set_size_inches(22, 15, forward=True)
real = plt.plot(values_original, label='real')
pred = plt.plot(values_predicted, label='predicted')
if len(buys) > 0:
    plt.scatter(list(list(zip(*buys))[0]), list(list(zip(*buys))[1]), c='#00ff00', s=50)
if len(sells) > 0:
    plt.scatter(list(list(zip(*sells))[0]), list(list(zip(*sells))[1]), c='#ff0000', s=50)
# real = plt.plot(unscaled_y[start:end], label='real')
# pred = plt.plot(y_predicted[start:end], label='predicted')
plt.legend(['Real', 'Predicted', 'Buy', 'Sell'])
# Delete the comment to save the plot
save_string = str(widget.kwargs['x']) + '.png'
plt.savefig(save_string)
plt.show()

# %%
# Network hyperparameters
two_lstm_layers=False
number_of_neurons_lstm=50 # Only use integers
two_layers_second_branch=False
number_of_neurons_second_branch=20 # Only use integers
dropout_rate=0.2

# Feature parameters
history_points = 50 # Do not set below 50; Only use integers
s_and_p_500 = True 
ma7 = False
ma21 = True 
ma_his_window = True
ema12 = True 
ema26 = False 
mac = False 
ten_day_momentum = True
upper_bands = False 
lower_bands = True
volatilty_index_feature = True
fourier = 0 # 0 if you don't want to use the feature and only use integers
dollar_currency_index = True

# Training parameters
number_of_epochs = 50
error, values_original, values_predicted, ohlcv_test, tech_ind_test, model, y_normaliser = train_bot(file_path=file_path, 
                                                                                                     history_points=history_points, 
                                                                                                     number_of_epochs=number_of_epochs, 
                                                                                                     two_lstm_layers=two_lstm_layers, 
                                                                                                     number_of_neurons_lstm=number_of_neurons_lstm,
                                                                                                     two_layers_second_branch=two_layers_second_branch, 
                                                                                                     number_of_neurons_second_branch=number_of_neurons_second_branch, 
                                                                                                     dropout_rate=dropout_rate, 
                                                                                                     s_and_p_500=s_and_p_500, 
                                                                                                     ma7=ma7, 
                                                                                                     ma21=ma21, 
                                                                                                     ma_his_window=ma_his_window, 
                                                                                                     ema12=ema12, 
                                                                                                     ema26=ema26, 
                                                                                                     mac=mac, 
                                                                                                     ten_day_momentum=ten_day_momentum,
                                                                                                     upper_bands=upper_bands, 
                                                                                                     lower_bands=lower_bands,
                                                                                                     volatilty_index_feature=volatilty_index_feature,
                                                                                                     fourier=fourier,
                                                                                                     dollar_currency_index=dollar_currency_index)
purchase_amt = 100 # Select here your purchase amount
trading_cost = 0 # Select your trading cost
buys, sells = trading(ohlcv_test, tech_ind_test, y_normaliser, model, purchase_amt, trading_cost)
# Out:
# Train on 4032 samples, validate on 448 samples
# Epoch 1/50
#  - 4s - loss: 0.0691 - val_loss: 0.0013
# Epoch 2/50
#  - 4s - loss: 0.0020 - val_loss: 7.3095e-04
# Epoch 3/50
#  - 4s - loss: 0.0016 - val_loss: 2.5274e-04
# Epoch 4/50
#  - 4s - loss: 0.0012 - val_loss: 3.4006e-04
# Epoch 5/50
#  - 4s - loss: 0.0012 - val_loss: 2.3283e-04
# Epoch 6/50
#  - 4s - loss: 0.0010 - val_loss: 2.3846e-04
# Epoch 7/50
#  - 4s - loss: 9.0607e-04 - val_loss: 3.2322e-04
# Epoch 8/50
#  - 4s - loss: 7.4439e-04 - val_loss: 2.1235e-04
# Epoch 9/50
#  - 4s - loss: 7.0654e-04 - val_loss: 2.6305e-04
# Epoch 10/50
#  - 5s - loss: 6.8688e-04 - val_loss: 3.3819e-04
# Epoch 11/50
#  - 4s - loss: 5.9221e-04 - val_loss: 5.0602e-04
# Epoch 12/50
#  - 5s - loss: 5.5070e-04 - val_loss: 2.8027e-04
# Epoch 13/50
#  - 4s - loss: 4.9538e-04 - val_loss: 3.0042e-04
# Epoch 14/50
#  - 4s - loss: 4.6885e-04 - val_loss: 2.7755e-04
# Epoch 15/50
#  - 4s - loss: 4.5451e-04 - val_loss: 1.9160e-04
# Epoch 16/50
#  - 4s - loss: 3.9728e-04 - val_loss: 1.6737e-04
# Epoch 17/50
#  - 4s - loss: 4.0196e-04 - val_loss: 1.5597e-04
# Epoch 18/50
#  - 4s - loss: 3.6753e-04 - val_loss: 2.5839e-04
# Epoch 19/50
#  - 4s - loss: 3.5463e-04 - val_loss: 2.4808e-04
# Epoch 20/50
#  - 4s - loss: 3.3751e-04 - val_loss: 1.7239e-04
# Epoch 21/50
#  - 4s - loss: 3.6593e-04 - val_loss: 1.7624e-04
# Epoch 22/50
#  - 4s - loss: 3.1728e-04 - val_loss: 1.9479e-04
# Epoch 23/50
#  - 4s - loss: 3.4608e-04 - val_loss: 1.6716e-04
# Epoch 24/50
#  - 4s - loss: 3.0613e-04 - val_loss: 2.7410e-04
# Epoch 25/50
#  - 5s - loss: 3.1741e-04 - val_loss: 1.5436e-04
# Epoch 26/50
#  - 4s - loss: 3.2633e-04 - val_loss: 2.3198e-04
# Epoch 27/50
#  - 4s - loss: 2.9616e-04 - val_loss: 1.5161e-04
# Epoch 28/50
#  - 4s - loss: 2.9072e-04 - val_loss: 1.4634e-04
# Epoch 29/50
#  - 3s - loss: 3.1269e-04 - val_loss: 2.0702e-04
# Epoch 30/50
#  - 4s - loss: 2.8292e-04 - val_loss: 1.7975e-04
# Epoch 31/50
#  - 3s - loss: 2.9593e-04 - val_loss: 1.4462e-04
# Epoch 32/50
#  - 3s - loss: 2.6919e-04 - val_loss: 1.4912e-04
# Epoch 33/50
#  - 3s - loss: 2.8475e-04 - val_loss: 2.7715e-04
# Epoch 34/50
#  - 3s - loss: 2.6343e-04 - val_loss: 2.3851e-04
# Epoch 35/50
#  - 3s - loss: 2.6085e-04 - val_loss: 1.6748e-04
# Epoch 36/50
#  - 4s - loss: 2.7677e-04 - val_loss: 1.7897e-04
# Epoch 37/50
#  - 3s - loss: 2.4948e-04 - val_loss: 1.3231e-04
# Epoch 38/50
#  - 3s - loss: 2.5016e-04 - val_loss: 1.6073e-04
# Epoch 39/50
#  - 3s - loss: 2.5536e-04 - val_loss: 1.1732e-04
# Epoch 40/50
#  - 3s - loss: 2.5540e-04 - val_loss: 1.4218e-04
# Epoch 41/50
#  - 3s - loss: 2.6132e-04 - val_loss: 1.0467e-04
# Epoch 42/50
#  - 3s - loss: 2.3253e-04 - val_loss: 1.5046e-04
# Epoch 43/50
#  - 3s - loss: 2.6268e-04 - val_loss: 1.4713e-04
# Epoch 44/50
#  - 3s - loss: 2.4497e-04 - val_loss: 1.8004e-04
# Epoch 45/50
#  - 3s - loss: 2.4782e-04 - val_loss: 1.5490e-04
# Epoch 46/50
#  - 3s - loss: 2.4831e-04 - val_loss: 1.1362e-04
# Epoch 47/50
#  - 3s - loss: 2.4741e-04 - val_loss: 1.0779e-04
# Epoch 48/50
#  - 3s - loss: 2.5270e-04 - val_loss: 1.3371e-04
# Epoch 49/50
#  - 3s - loss: 2.5343e-04 - val_loss: 1.0250e-04
# Epoch 50/50
#  - 3s - loss: 2.5989e-04 - val_loss: 3.0905e-04
# 43.164288511750506
# Finished training
# The numbers of buys and sells that our bot would have taken
# buys: 9
# sells: 8
# The money our bot would have earned
# earnings: $28.170141829520787

# %%
plt.gcf().set_size_inches(22, 15, forward=True)
real = plt.plot(values_original, label='real')
pred = plt.plot(values_predicted, label='predicted')
if len(buys) > 0:
    plt.scatter(list(list(zip(*buys))[0]), list(list(zip(*buys))[1]), c='#00ff00', s=50)
if len(sells) > 0:
    plt.scatter(list(list(zip(*sells))[0]), list(list(zip(*sells))[1]), c='#ff0000', s=50)
# real = plt.plot(unscaled_y[start:end], label='real')
# pred = plt.plot(y_predicted[start:end], label='predicted')
plt.legend(['Real', 'Predicted', 'Buy', 'Sell'])
# Delete the comment to save the plot
save_string = str(widget.kwargs['x']) + '.png'
plt.savefig(save_string)
plt.show()
